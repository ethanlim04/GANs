# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = 'PCI_BUS_ID'
os.environ["CUDA_VISIBLE_DEVICES"] = "0, 1, 2, 3"

# %%
import torch
torch.cuda.set_device(0)
print(torch.cuda.is_available())
print(os.environ["CUDA_VISIBLE_DEVICES"])
print("Current device:", torch.cuda.current_device())
print("Device count:", torch.cuda.device_count())
# Out:
# True
# 0, 1, 2, 3
# Current device: 0
# Device count: 4

# %%
import os
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as tt
import torch
import torch.nn as nn
import cv2
from tqdm.notebook import tqdm
import torch.nn.functional as F
from torchvision.utils import save_image
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dir = '../cat_faces'
print(os.listdir(dir))
# Out:
# ['cats']

# %%
# image_size = 64
image_size = 128
batch_size = 128
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

train_ds = ImageFolder(dir, transform=tt.Compose([ tt.Resize(image_size),
                                                        tt.CenterCrop(image_size),
                                                        tt.ToTensor(),
                                                        tt.Normalize(*stats)]))

train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=3, pin_memory=True)

# %%
def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()[:nmax]), nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

# %%
def is_cuda_available():
    if torch.cuda.is_available():
        print("CUDA available. Training on GPU!")
        return torch.device('cuda')
    else:
        print("CUDA not available. Training on CPU!")
        return torch.device('cpu')
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)
device=is_cuda_available()
# device = torch.device("cuda")
train_dl = DeviceDataLoader(train_dl, device)
# Out:
# CUDA available. Training on GPU!

# %%
discriminator = nn.Sequential(
    # in: 3 x 128 x 128

    nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 64 x 64 x 64

    nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 128 x 32 x 32

    nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 256 x 16 x 16

    nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 512 x 8 x 8
    
    nn.Conv2d(512, 1024, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(1024),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 1024 x 4 x 4

    nn.Conv2d(1024, 1, kernel_size=4, stride=1, padding=0, bias=False),
    # out: 1 x 1 x 1

    nn.Flatten(),
    nn.Sigmoid())

latent_size = 256
generator = nn.Sequential(
    # in: latent_size x 1 x 1

    
    #NEEDED TO CHANGE
    nn.ConvTranspose2d(latent_size, 1024, kernel_size=4, stride=1, padding=0, bias=False),
    nn.BatchNorm2d(1024),
    nn.ReLU(True),
    # out: 1024 x 4 x 4 ???????
    
    #NEEDED TO ADD
    nn.ConvTranspose2d(1024, 512, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(512),
    nn.ReLU(True),
    # out: 512 x 8 x 8

    nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    # out: 256 x 16 x 16

    nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    # out: 128 x 32 x 32

    nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    # out: 64 x 64 x 64

    nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1, bias=False),
    nn.Tanh()
    # out: 3 x 128 x 128
)

discriminator = to_device(discriminator, device)
generator = to_device(generator, device)

# %%
sample_dir = 'generated2'
os.makedirs(sample_dir, exist_ok=True)
def save_samples(index, latent_tensors, show=True):
    fake_images = generator(latent_tensors)
    fake_fname = 'generated-images-{0:0=4d}.png'.format(index)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=8)
    print('Saving', fake_fname)
    if show:
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(fake_images.cpu().detach(), nrow=8).permute(1, 2, 0))

import numpy
fixed_latent = torch.randn(128, latent_size, 1, 1, device=device)
numpy.shape(fixed_latent)
# Out:
# torch.Size([128, 256, 1, 1])

# %%
save_samples(0, fixed_latent)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving generated-images-0000.png

# %%
def train_discriminator(real_images, opt_d):
    # Clear discriminator gradients
    opt_d.zero_grad()

    # Pass real images through discriminator
    real_preds = discriminator(real_images)
    real_targets = torch.ones(real_images.size(0), 1, device=device)
    real_loss = F.binary_cross_entropy(real_preds, real_targets)
    real_score = torch.mean(real_preds).item()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)

    # Pass fake images through discriminator
    fake_targets = torch.zeros(fake_images.size(0), 1, device=device)
    fake_preds = discriminator(fake_images)
    fake_loss = F.binary_cross_entropy(fake_preds, fake_targets)
    fake_score = torch.mean(fake_preds).item()

    # Update discriminator weights
    loss = real_loss + fake_loss
    loss.backward()
    opt_d.step()
    return loss.item(), real_score, fake_score
def train_generator(opt_g):
    # Clear generator gradients
    opt_g.zero_grad()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)
    
    # Try to fool the discriminator
    preds = discriminator(fake_images)
    targets = torch.ones(batch_size, 1, device=device)
    loss = F.binary_cross_entropy(preds, targets)
    
    # Update generator weights
    loss.backward()
    opt_g.step()
    
    return loss.item()

# %%
def fit(epochs, lr, start_idx=1):
    torch.cuda.empty_cache()
    
    # Losses & scores
    losses_g = []
    losses_d = []
    real_scores = []
    fake_scores = []
    
    # Create optimizers
    opt_d = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_g = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
#     opt_d = torch.optim.SGD(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
#     opt_g = torch.optim.SGD(generator.parameters(), lr=lr, betas=(0.5, 0.999))
    
    for epoch in range(epochs):
        for real_images, _ in tqdm(train_dl):
            # Train discriminator
            loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)
            # Train generator
            loss_g = train_generator(opt_g)
            
        # Record losses & scores
        losses_g.append(loss_g)
        losses_d.append(loss_d)
        real_scores.append(real_score)
        fake_scores.append(fake_score)
        
        # Log losses & scores (last batch)
        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, loss_g, loss_d, real_score, fake_score))
    
        # Save generated images
        save_samples(epoch+start_idx, fixed_latent, show=False)
    
    return losses_g, losses_d, real_scores, fake_scores

# %%
lr = 0.0003
epochs = 60

# %%
history=fit(epochs,lr)
# Out:
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [1/60], loss_g: 3.6862, loss_d: 1.5433, real_score: 0.3240, fake_score: 0.0084
# Saving generated-images-0001.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [2/60], loss_g: 4.7289, loss_d: 0.6885, real_score: 0.5687, fake_score: 0.0443
# Saving generated-images-0002.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [3/60], loss_g: 3.5865, loss_d: 0.5079, real_score: 0.9574, fake_score: 0.3481
# Saving generated-images-0003.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [4/60], loss_g: 5.0820, loss_d: 1.3171, real_score: 0.8147, fake_score: 0.6096
# Saving generated-images-0004.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [5/60], loss_g: 2.7766, loss_d: 0.8421, real_score: 0.9548, fake_score: 0.5200
# Saving generated-images-0005.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [6/60], loss_g: 2.3218, loss_d: 1.1194, real_score: 0.6545, fake_score: 0.4417
# Saving generated-images-0006.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [7/60], loss_g: 3.8677, loss_d: 1.1657, real_score: 0.7351, fake_score: 0.5000
# Saving generated-images-0007.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [8/60], loss_g: 2.8536, loss_d: 0.4116, real_score: 0.8254, fake_score: 0.1871
# Saving generated-images-0008.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [9/60], loss_g: 0.4693, loss_d: 2.5361, real_score: 0.1549, fake_score: 0.2997
# Saving generated-images-0009.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [10/60], loss_g: 0.6280, loss_d: 2.0210, real_score: 0.2561, fake_score: 0.4134
# Saving generated-images-0010.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [11/60], loss_g: 2.0694, loss_d: 0.9013, real_score: 0.8307, fake_score: 0.4901
# Saving generated-images-0011.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [12/60], loss_g: 3.0591, loss_d: 0.5431, real_score: 0.8996, fake_score: 0.3393
# Saving generated-images-0012.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [13/60], loss_g: 0.7597, loss_d: 1.2669, real_score: 0.4363, fake_score: 0.3138
# Saving generated-images-0013.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [14/60], loss_g: 3.3169, loss_d: 0.6368, real_score: 0.8916, fake_score: 0.3906
# Saving generated-images-0014.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [15/60], loss_g: 1.4416, loss_d: 0.9477, real_score: 0.4398, fake_score: 0.0833
# Saving generated-images-0015.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [16/60], loss_g: 5.2859, loss_d: 0.4757, real_score: 0.9909, fake_score: 0.3631
# Saving generated-images-0016.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [17/60], loss_g: 2.5062, loss_d: 0.4784, real_score: 0.8858, fake_score: 0.2891
# Saving generated-images-0017.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [18/60], loss_g: 1.6973, loss_d: 1.4195, real_score: 0.9450, fake_score: 0.6899
# Saving generated-images-0018.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [19/60], loss_g: 3.6243, loss_d: 0.0745, real_score: 0.9770, fake_score: 0.0489
# Saving generated-images-0019.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [20/60], loss_g: 4.3891, loss_d: 0.0523, real_score: 0.9998, fake_score: 0.0505
# Saving generated-images-0020.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [21/60], loss_g: 3.1386, loss_d: 0.0651, real_score: 0.9939, fake_score: 0.0569
# Saving generated-images-0021.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [22/60], loss_g: 1.3964, loss_d: 0.5991, real_score: 0.6482, fake_score: 0.0958
# Saving generated-images-0022.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [23/60], loss_g: 1.0519, loss_d: 1.7858, real_score: 0.2453, fake_score: 0.2082
# Saving generated-images-0023.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [24/60], loss_g: 1.2469, loss_d: 1.7801, real_score: 0.2329, fake_score: 0.1102
# Saving generated-images-0024.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [25/60], loss_g: 0.8028, loss_d: 1.6270, real_score: 0.2406, fake_score: 0.1185
# Saving generated-images-0025.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [26/60], loss_g: 0.2301, loss_d: 3.0141, real_score: 0.0795, fake_score: 0.0746
# Saving generated-images-0026.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [27/60], loss_g: 5.4844, loss_d: 0.9253, real_score: 0.8810, fake_score: 0.5206
# Saving generated-images-0027.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [28/60], loss_g: 1.7631, loss_d: 2.6032, real_score: 0.0911, fake_score: 0.0050
# Saving generated-images-0028.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [29/60], loss_g: 1.7334, loss_d: 0.1511, real_score: 0.9063, fake_score: 0.0494
# Saving generated-images-0029.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [30/60], loss_g: 3.1787, loss_d: 0.1828, real_score: 0.9913, fake_score: 0.1543
# Saving generated-images-0030.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [31/60], loss_g: 0.4997, loss_d: 0.8340, real_score: 0.5884, fake_score: 0.1804
# Saving generated-images-0031.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [32/60], loss_g: 4.8783, loss_d: 1.1984, real_score: 0.9729, fake_score: 0.6466
# Saving generated-images-0032.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [33/60], loss_g: 1.4308, loss_d: 0.2866, real_score: 0.9097, fake_score: 0.1569
# Saving generated-images-0033.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [34/60], loss_g: 3.1050, loss_d: 0.3335, real_score: 0.7996, fake_score: 0.0542
# Saving generated-images-0034.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [35/60], loss_g: 3.2253, loss_d: 0.3731, real_score: 0.8247, fake_score: 0.1425
# Saving generated-images-0035.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [36/60], loss_g: 2.9047, loss_d: 0.6552, real_score: 0.8422, fake_score: 0.3478
# Saving generated-images-0036.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [37/60], loss_g: 6.1854, loss_d: 0.7989, real_score: 0.9392, fake_score: 0.4835
# Saving generated-images-0037.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [38/60], loss_g: 5.2362, loss_d: 0.4364, real_score: 0.9722, fake_score: 0.2987
# Saving generated-images-0038.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [39/60], loss_g: 1.1310, loss_d: 0.8727, real_score: 0.6397, fake_score: 0.0635
# Saving generated-images-0039.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [40/60], loss_g: 3.0998, loss_d: 0.3566, real_score: 0.7875, fake_score: 0.0949
# Saving generated-images-0040.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [41/60], loss_g: 4.0804, loss_d: 0.3052, real_score: 0.9245, fake_score: 0.1926
# Saving generated-images-0041.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [42/60], loss_g: 9.5366, loss_d: 0.9969, real_score: 0.9653, fake_score: 0.5638
# Saving generated-images-0042.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [43/60], loss_g: 3.8542, loss_d: 0.2586, real_score: 0.8942, fake_score: 0.1270
# Saving generated-images-0043.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [44/60], loss_g: 3.2281, loss_d: 0.3984, real_score: 0.7633, fake_score: 0.0833
# Saving generated-images-0044.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [45/60], loss_g: 3.3246, loss_d: 0.6191, real_score: 0.8048, fake_score: 0.2746
# Saving generated-images-0045.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [46/60], loss_g: 2.8729, loss_d: 0.4609, real_score: 0.6932, fake_score: 0.0543
# Saving generated-images-0046.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [47/60], loss_g: 2.5881, loss_d: 0.3872, real_score: 0.8220, fake_score: 0.1546
# Saving generated-images-0047.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [48/60], loss_g: 2.6112, loss_d: 1.4761, real_score: 0.3886, fake_score: 0.0745
# Saving generated-images-0048.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [49/60], loss_g: 4.3575, loss_d: 0.7673, real_score: 0.6791, fake_score: 0.0908
# Saving generated-images-0049.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [50/60], loss_g: 3.7238, loss_d: 0.2252, real_score: 0.9312, fake_score: 0.1331
# Saving generated-images-0050.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [51/60], loss_g: 5.4104, loss_d: 0.0870, real_score: 0.9725, fake_score: 0.0562
# Saving generated-images-0051.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [52/60], loss_g: 1.3407, loss_d: 1.5289, real_score: 0.2795, fake_score: 0.2057
# Saving generated-images-0052.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [53/60], loss_g: 2.5575, loss_d: 0.3518, real_score: 0.7683, fake_score: 0.0782
# Saving generated-images-0053.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [54/60], loss_g: 4.1914, loss_d: 0.1212, real_score: 0.9818, fake_score: 0.0912
# Saving generated-images-0054.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [55/60], loss_g: 5.5319, loss_d: 0.1889, real_score: 0.9795, fake_score: 0.1390
# Saving generated-images-0055.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [56/60], loss_g: 0.7892, loss_d: 1.0154, real_score: 0.4102, fake_score: 0.0696
# Saving generated-images-0056.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [57/60], loss_g: 3.1888, loss_d: 2.2179, real_score: 0.2860, fake_score: 0.2490
# Saving generated-images-0057.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [58/60], loss_g: 1.5302, loss_d: 0.2967, real_score: 0.8219, fake_score: 0.0765
# Saving generated-images-0058.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [59/60], loss_g: 0.9643, loss_d: 2.8094, real_score: 0.1794, fake_score: 0.0096
# Saving generated-images-0059.png
#   0%|          | 0/124 [00:00<?, ?it/s]
# Epoch [60/60], loss_g: 1.7045, loss_d: 0.9851, real_score: 0.4737, fake_score: 0.0044
# Saving generated-images-0060.png

# %%
from IPython.display import Image
Image('./generated2/generated-images-0280.png')
